# %% [markdown]
# ### Assignment: Comprehensive Analysis of the Iris Dataset
#
# #### Objective:
# Your task is to conduct a detailed analysis of the Iris dataset using Pandas and NumPy. You will perform data cleaning, analysis, and visualization, incorporating functions (`def`), conditional statements (`if`), and loops (`for`). The goal is to uncover insights about iris species, petal and sepal measurements, and their distributions.
#
# #### Dataset:
# You will use the famous Iris dataset, which can be loaded from the following URL:
# [IRIS Dataset](https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data)
#
# #### Tasks:
#
# 1. **Load and Prepare the Dataset**:
#     - Use Pandas to load the dataset from the URL into a DataFrame.
#     - Display basic information about the DataFrame including column names, data types, and the first few rows.
#
# 2. **Data Cleaning**:
#     - **Rename Columns**: Rename columns to `sepal_length`, `sepal_width`, `petal_length`, `petal_width`, and `species` for clarity.
#     - **Handle Missing Values**: Identify and handle any missing or null values in the dataset.
#
# 3. **Data Analysis**:
#     - **Function 1**: Define a function `species_statistics(df)` that returns the count of samples for each iris species.
#     - **Function 2**: Define a function `average_measurements_by_species(df)` that calculates and returns the average measurements of sepal length, sepal width, petal length, and petal width for each species.
#     - **Function 3**: Define a function `species_correlation(df)` that calculates and returns the correlation matrix of measurements for each species.
#
# 4. **Advanced Analysis**:
#     - **Species Statistics**: Use the function `species_statistics()` to print the number of samples for each species.
#     - **Average Measurements**: Use the function `average_measurements_by_species()` to display the average measurements for each species.
#     - **Correlation Matrix**: Use the function `species_correlation()` to display the correlation matrix for each species.
#
# 5. **Data Visualization**:
#     - **Scatter Plots**: Create scatter plots to visualize the relationships between sepal length and sepal width, and petal length and petal width, colored by species.
#     - **Pair Plot**: Create a pair plot to visualize the distributions and relationships between all pairs of measurements.
#
# #### Deliverables:
# - A Python script or Jupyter Notebook containing the complete code.
# - Comments and markdown cells explaining each step of your analysis.
# - Plots and visualizations as required.
# - Summary of findings as described above.

# %%
import pandas as pd

# %%
df=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   5.1          149 non-null    float64
#  1   3.5          149 non-null    float64
#  2   1.4          149 non-null    float64
#  3   0.2          149 non-null    float64
#  4   Iris-setosa  149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
df.describe()
# Out:
#               5.1         3.5         1.4         0.2
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df.columns=['sepal_length','sepal_width','petal_length','petal_width','species']
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
def species_statistics(df):
    species_counts = df['species'].value_counts()
    return species_counts
# Out:
# species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64

# %%
df.groupby("species").mean()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa          5.004082     3.416327      1.465306     0.244898
# Iris-versicolor      5.936000     2.770000      4.260000     1.326000
# Iris-virginica       6.588000     2.974000      5.552000     2.026000

# %%
df.groupby("species").corr()
# Out:
#                               sepal_length  sepal_width  petal_length  \
# species
# Iris-setosa     sepal_length      1.000000     0.746498      0.266497
#                 sepal_width       0.746498     1.000000      0.178687
#                 petal_length      0.266497     0.178687      1.000000
#                 petal_width       0.282074     0.282444      0.304120
# Iris-versicolor sepal_length      1.000000     0.525911      0.754049
#                 sepal_width       0.525911     1.000000      0.560522
#                 petal_length      0.754049     0.560522      1.000000
#                 petal_width       0.546461     0.663999      0.786668
# Iris-virginica  sepal_length      1.000000     0.457228      0.864225
#                 sepal_width       0.457228     1.000000      0.401045
#                 petal_length      0.864225     0.401045      1.000000
#                 petal_width       0.281108     0.537728      0.322108
#
#                               petal_width
# ...

# %%
df['species'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='species'>

# %%
df.groupby("species").mean().plot(kind='bar')
# Out:
# <Axes: xlabel='species'>

# %%
df.groupby("species").corr().plot(kind='bar')
# Out:
# <Axes: xlabel='species,None'>

# %%
df.shape
# Out:
# (149, 5)
